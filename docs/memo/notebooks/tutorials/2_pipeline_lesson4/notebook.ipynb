# %% [markdown]
# ## Combining Factors
# Factors can be combined, both with other Factors and with scalar values, via any of the builtin mathematical operators (+, -, *, etc). This makes it easy to write complex expressions that combine multiple Factors. For example, constructing a Factor that computes the average of two other Factors is simply:
# ```
# >>> f1 = SomeFactor(...)
# >>> f2 = SomeOtherFactor(...)
# >>> average = (f1 + f2) / 2.0
# ```
# In this lesson, we will create a pipeline that creates a `relative_difference` factor by combining a 10-day average factor and a 30-day average factor.
#
# As usual, let's start with our imports:

# %%
from zipline.pipeline import Pipeline
from zipline.component.research import run_pipeline
from zipline.pipeline.data import USEquityPricing
from zipline.pipeline.factors import SimpleMovingAverage

# %% [markdown]
# For this example, we need two factors: a 10-day mean close price factor, and a 30-day one:

# %%
mean_close_10 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=10)
mean_close_30 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=30)

# %% [markdown]
# Then, let's create a percent difference factor by combining our `mean_close_30` factor with our `mean_close_10` factor.

# %%
percent_difference = (mean_close_10 - mean_close_30) / mean_close_30

# %% [markdown]
# In this example, `percent_difference` is still a `Factor` even though it's composed as a combination of more primitive factors. We can add `percent_difference` as a column in our pipeline. Let's define `make_pipeline` to create a pipeline with `percent_difference` as a column (and not the mean close factors):

# %%
def make_pipeline():

    mean_close_10 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=10)
    mean_close_30 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=30)

    percent_difference = (mean_close_10 - mean_close_30) / mean_close_30

    return Pipeline(
        columns={
            'percent_difference': percent_difference
        }
    )

# %% [markdown]
# Let's see what the new output looks like:

# %%
result = run_pipeline(make_pipeline(), '2015-05-05', '2015-05-05')
result
# Out:
#                                                  percent_difference
# 2015-05-05 00:00:00+00:00 Equity(000001 [平安银行])        1.051446e-01
#                           Equity(000002 [万 科Ａ])        3.509064e-02
#                           Equity(000004 [国农科技])        1.675352e-02
#                           Equity(000005 [世纪星源])        6.498866e-16
#                           Equity(000006 [深振业Ａ])        1.358370e-01
#                           Equity(000007 [全新好])         1.161545e-01
#                           Equity(000008 [神州高铁])       -1.322186e-16
#                           Equity(000009 [中国宝安])        1.007447e-01
#                           Equity(000010 [美丽生态])       -4.800964e-16
#                           Equity(000011 [深物业A])        8.656137e-02
#                           Equity(000012 [南 玻Ａ])        1.357192e-01
#                           Equity(000014 [沙河股份])        8.347065e-03
#                           Equity(000016 [深康佳Ａ])        1.707698e-01
#                           Equity(000017 [深中华A])        1.785772e-01
#                           Equity(000018 [神州长城])        8.251318e-02
#                           Equity(000019 [深深宝Ａ])        1.061686e-01
#                           Equity(000020 [深华发Ａ])        7.462655e-02
#                           Equity(000021 [深科技])         7.453298e-02
#                           Equity(000022 [深赤湾Ａ])        7.563894e-02
#                           Equity(000023 [深天地Ａ])       -1.246282e-02
#                           Equity(000024 [招商地产])        2.147788e-02
#                           Equity(000025 [特 力Ａ])       -3.048537e-02
#                           Equity(000026 [飞亚达Ａ])        4.618202e-02
#                           Equity(000027 [深圳能源])        4.882813e-02
#                           Equity(000028 [国药一致])        6.102351e-02
#                           Equity(000029 [深深房Ａ])        5.863756e-02
#                           Equity(000030 [富奥股份])        9.711013e-02
#                           Equity(000031 [中粮地产])        9.336966e-02
#                           Equity(000032 [深桑达Ａ])        1.449139e-01
#                           Equity(000033 [新都退])         3.766730e-01
# ...                                                             ...
#                           Equity(603609 [禾丰牧业])        6.490884e-02
#                           Equity(603611 [诺力股份])        1.874702e-02
#                           Equity(603618 [杭电股份])        4.370550e-02
#                           Equity(603636 [南威软件])        4.376079e-02
#                           Equity(603678 [火炬电子])        1.368253e-01
#                           Equity(603686 [龙马环卫])        3.197340e-01
#                           Equity(603688 [石英股份])        4.313702e-02
#                           Equity(603698 [航天工程])        4.446789e-02
#                           Equity(603699 [纽威股份])        3.824992e-02
#                           Equity(603703 [盛洋科技])        0.000000e+00
#                           Equity(603729 [龙韵股份])        1.360256e-01
#                           Equity(603766 [隆鑫通用])        9.357173e-02
#                           Equity(603788 [宁波高发])        6.526972e-02
#                           Equity(603789 [星光农机])        0.000000e+00
#                           Equity(603799 [华友钴业])        9.184731e-02
#                           Equity(603806 [福斯特])         1.204509e-01
#                           Equity(603808 [歌力思])         0.000000e+00
#                           Equity(603818 [曲美家居])        0.000000e+00
#                           Equity(603828 [柯利达])         4.118794e-02
#                           Equity(603869 [北部湾旅])        3.789677e-01
#                           Equity(603883 [老百姓])         0.000000e+00
#                           Equity(603889 [新澳股份])        6.142140e-02
#                           Equity(603898 [好莱客])         1.707971e-02
#                           Equity(603899 [晨光文具])        4.176201e-02
#                           Equity(603939 [益丰药房])        1.383420e-01
#                           Equity(603969 [银龙股份])        9.436443e-02
#                           Equity(603988 [中电电机])        4.818382e-02
#                           Equity(603993 [洛阳钼业])        9.443979e-02
#                           Equity(603997 [继峰股份])        2.834925e-02
#                           Equity(603998 [方盛制药])        7.586807e-02
#
# [2702 rows x 1 columns]

# %% [markdown]
# In the next lesson, we will learn about filters.
