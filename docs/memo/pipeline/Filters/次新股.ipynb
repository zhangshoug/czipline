# %%
# %load_ext zipline

# %%
# %%zipline --start 2017-11-1 --end 2017-11-26 --capital-base 100000
#
# from zipline.pipeline import Pipeline, Fundamentals
#
# from zipline.pipeline.factors import CustomFactor
#
# from zipline.pipeline.builtin import filter_universe, SubNewStocks, NDays
#
# from zipline.pipeline.data import USEquityPricing
# from zipline.api import attach_pipeline, pipeline_output
#
# from zipline.api import symbol, sid, get_datetime
#
#
# def make_pipeline():
#     dates = Fundamentals.time_to_market.latest
#     return Pipeline(
#         columns = {
#             '收盘价':USEquityPricing.close.latest,
#             '上市日期':Fundamentals.time_to_market.latest,
#             '上市天数':NDays()
#         },
#         screen = SubNewStocks()
#     )
#
# def initialize(context):
#     attach_pipeline(make_pipeline(), 'example')
#
# def handle_data(context, data):
#     today = get_datetime('Asia/Shanghai')
#     output = pipeline_output('example')
#     print(output) #.loc[[sid(1),sid(100001)],:])
# Out:
# [2017-12-09 17:49:10.758806] INFO: Loader: Read benchmark and treasury data for 000300 from 1990-10-31 to 2017-12-08
#                        上市天数       上市日期     收盘价
# Equity(002893 [华通热力])  47.0 2017-09-15   28.79
# Equity(002897 [意华股份])  55.0 2017-09-07   43.09
# Equity(002898 [赛隆药业])  50.0 2017-09-12   26.09
# Equity(002899 [英派斯])   47.0 2017-09-15   35.46
# Equity(002900 [哈三联])   40.0 2017-09-22   35.63
# Equity(002901 [大博医疗])  40.0 2017-09-22   39.96
# Equity(002902 [铭普光磁])  33.0 2017-09-29   45.58
# Equity(002903 [宇环数控])  19.0 2017-10-13   52.49
# Equity(002905 [金逸影视])  16.0 2017-10-16   43.61
# Equity(002906 [华阳集团])  19.0 2017-10-13   28.32
# Equity(002907 [华森制药])  12.0 2017-10-20   12.72
# Equity(002908 [德生科技])  12.0 2017-10-20   21.27
# Equity(002909 [集泰股份])   6.0 2017-10-26   14.32
# Equity(002910 [庄园牧场])   1.0 2017-10-31   10.74
# Equity(300654 [世纪天鸿])  36.0 2017-09-26   29.71
# Equity(300695 [兆丰股份])  54.0 2017-09-08  107.17
# ...
