# %%
# %load_ext zipline

# %%
from zipline.pipeline import Fundamentals
Fundamentals.cninfo.columns
# Out:
# frozenset({cninfo.asof_date::datetime64[ns],
#            cninfo.group::object,
#            cninfo.industry::object,
#            cninfo.sector::int64,
#            cninfo.supper_sector::int64})

# %%
# %%zipline --start 2012-11-1 --end 2012-11-24 --capital-base 100000
#
# from zipline.pipeline import Pipeline, Fundamentals
#
# from zipline.pipeline.factors import CustomFactor
# from zipline.pipeline.data import USEquityPricing
# from zipline.api import attach_pipeline, pipeline_output
#
# from zipline.api import symbol, sid, get_datetime
#
# def make_pipeline():
#     return Pipeline(
#         columns = {
#             'industry':Fundamentals.cninfo.industry.latest,
#             'group':Fundamentals.cninfo.group.latest,
#             'sector':Fundamentals.cninfo.sector.latest,
#             'supper_sector':Fundamentals.cninfo.supper_sector.latest,
#         }
#     )
#
# def initialize(context):
#     attach_pipeline(make_pipeline(), 'example')
#
# def handle_data(context, data):
#     today = get_datetime('Asia/Shanghai')
#     print('\n', today)
#     output = pipeline_output('example')
#     print(output.head())
#     print(output.tail())
# Out:
#  2012-11-01 15:00:00+08:00
#                       group  industry  sector  supper_sector
# Equity(000001 [平安银行])    银行        银行     103              1
# Equity(000002 [万 科Ａ])   房地产  房地产开发和管理     104              1
# Equity(000004 [国农科技])    制药      化学制剂     206              2
# Equity(000005 [世纪星源])   房地产     房地产服务     104              1
# Equity(000006 [深振业Ａ])   房地产  房地产开发和管理     104              1
#                           group industry  sector  supper_sector
# Equity(603333 [明星电缆])       工业品  电气部件与设备     310              3
# Equity(603366 [日出东方])     耐用消费品     家用电器     102              1
# Equity(603399 [新华龙])       基础材料     有色金属     101              1
# Equity(603766 [隆鑫通用])  汽车与汽车零配件       汽车     102              1
# Equity(603993 [洛阳钼业])      基础材料     有色金属     101              1
#
#  2012-11-02 15:00:00+08:00
#                       group  industry  sector  supper_sector
# Equity(000001 [平安银行])    银行        银行     103              1
# ...
