# %% [markdown]
# # `class BoundColumn`

# %% [markdown]
# A column of data that's been concretely bound to a particular dataset.
# Instances of this class are dynamically created upon access to attributes of DataSets (for example, USEquityPricing.close is an instance of this class).

# %% [markdown]
# ## `dtype`

# %% [markdown]
# `numpy.dtype` -- The dtype of data produced when this column is loaded.

# %% [markdown]
# ## `latest`

# %% [markdown]
# `zipline.pipeline.data.Factor` or `zipline.pipeline.data.Filter` -- A `Filter`, `Factor`, or `Classifier` computing the most recently known value of this column on each date.
# Produces a `Filter` if `self.dtype == np.bool_`. Produces a `Classifier` if `self.dtype == np.int64` Otherwise produces a `Factor`.

# %% [raw]
# Fundamentals.region.name.latest.dtype
# dtype('O')
# 检查是否支持为`Classifier`

# %% [markdown]
# ## `dataset`

# %% [markdown]
# `zipline.pipeline.data.DataSet` -- The dataset to which this column is bound.

# %% [markdown]
# ## `name`

# %% [markdown]
# str -- The name of this column.

# %% [markdown]
# ## `metadata`

# %% [markdown]
# dict -- Extra metadata associated with this column.

# %% [markdown]
# ## `qualname`

# %% [markdown]
# The fully-qualified name of this column.
# Generated by doing `'.'.join([self.dataset.__name__, self.name])`.
