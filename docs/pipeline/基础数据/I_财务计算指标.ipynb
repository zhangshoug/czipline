# %%
# %load_ext zipline

# %%
# %%zipline --start 2017-11-14 --end 2017-11-29 --capital-base 100000 --bm_symbol 000001
#
# from zipline.pipeline import Pipeline, Fundamentals
#
# from zipline.pipeline.factors import CustomFactor
# from zipline.pipeline.data import USEquityPricing
# from zipline.pipeline.builtin import PE, TTMSale, CNN
#
# from zipline.api import attach_pipeline, pipeline_output
# from zipline.api import symbol, sid, get_datetime
#
# def make_pipeline():
#     return Pipeline(
#         columns = {
#             'PE':PE(), #.downsample('quarter_start'),
#             'TTM Sales':TTMSale(mask=CNN(10)), #.downsample('quarter_start'),
#             '利息收入':Fundamentals.income_statement.B003.latest #.downsample('quarter_start'),
#         },
#         screen = CNN(2)
#     )
#
# def initialize(context):
#     attach_pipeline(make_pipeline(), 'example')
#
# def handle_data(context, data):
#     today = get_datetime('Asia/Shanghai')
#     print('\n', today)
#     output = pipeline_output('example')
#     print(output.head())
# Out:
# [2017-12-09 17:54:40.557655] INFO: Loader: Read benchmark and treasury data for 000001 from 1990-10-31 to 2017-12-08
#
#  2017-11-14 15:00:00+08:00
#                               PE     TTM Sales       利息收入
# Equity(000725 [京东方Ａ])  26.708333  8.184187e+10        0.0
# Equity(601318 [中国平安])  14.434156  9.008517e+11  7147400.0
#
#  2017-11-15 15:00:00+08:00
#                               PE     TTM Sales        利息收入
# Equity(000725 [京东方Ａ])  24.197368  8.451752e+10         0.0
# Equity(601318 [中国平安])  14.197581  8.966408e+11  10844400.0
#
#  2017-11-16 15:00:00+08:00
#                               PE     TTM Sales        利息收入
# Equity(000725 [京东方Ａ])  24.552632  8.451752e+10         0.0
# Equity(601318 [中国平安])  13.951613  8.966408e+11  10844400.0
#
#  2017-11-17 15:00:00+08:00
#                               PE     TTM Sales        利息收入
# Equity(000725 [京东方Ａ])  25.342105  8.451752e+10         0.0
# Equity(601318 [中国平安])  14.719758  8.966408e+11  10844400.0
#
# ...
