# %%
# %load_ext zipline

# %%
from zipline.pipeline import Fundamentals

# %%
Fundamentals.treatment
# Out:
# treatment.treatment::object

# %%
# %%zipline --start 2017-11-1 --end 2017-11-24 --capital-base 100000
#
# from zipline.pipeline import Pipeline, Fundamentals
#
# from zipline.pipeline.factors import CustomFactor
# from zipline.pipeline.data import USEquityPricing
# from zipline.api import attach_pipeline, pipeline_output
#
# from zipline.api import symbol, sid, get_datetime
#
# def make_pipeline():
#     return Pipeline(
#         columns = {
#             'treatment':Fundamentals.treatment.latest,
#         },
#     )
#
# def initialize(context):
#     attach_pipeline(make_pipeline(), 'example')
#
# def handle_data(context, data):
#     today = get_datetime('Asia/Shanghai')
#     print('\n', today)
#     output = pipeline_output('example')
#     print(output.sample(frac=0.1))
# Out:
# [2017-12-09 16:28:17.805909] INFO: Loader: Read benchmark and treasury data for 000300 from 1990-10-31 to 2017-12-08
#
#  2017-11-01 15:00:00+08:00
#                       treatment
# Equity(000979 [中弘股份])    撤销特别处理
# Equity(600850 [华东电脑])       新上市
# Equity(300052 [中青宝])        新上市
# Equity(600613 [神奇制药])    撤销特别处理
# Equity(600242 [中昌数据])    撤销特别处理
# Equity(300382 [斯莱克])        新上市
# Equity(300687 [赛意信息])       新上市
# Equity(601137 [博威合金])       新上市
# Equity(603960 [克来机电])       新上市
# Equity(600486 [扬农化工])       新上市
# Equity(600230 [沧州大化])    撤销特别处理
# Equity(600756 [浪潮软件])       新上市
# Equity(600641 [万业企业])       新上市
# Equity(600346 [恒力股份])    撤销特别处理
# Equity(002195 [二三四五])       新上市
# Equity(600567 [山鹰纸业])       新上市
# Equity(300244 [迪安诊断])       新上市
# Equity(300579 [数字认证])       新上市
# Equity(600657 [信达地产])    撤销特别处理
# Equity(002860 [星帅尔])        新上市
# Equity(002272 [川润股份])       新上市
# Equity(600026 [中远海能])       新上市
# Equity(002656 [摩登大道])       新上市
# Equity(600478 [科力远])        新上市
# Equity(603861 [白云电器])       新上市
# Equity(300289 [利德曼])        新上市
# Equity(002053 [云南能投])       新上市
# Equity(600778 [友好集团])       新上市
# Equity(600581 [八一钢铁])    撤销特别处理
# Equity(300449 [汉邦高科])       新上市
# ...                         ...
# Equity(603037 [凯众股份])       新上市
# Equity(000691 [亚太实业])    实施特别处理
# Equity(000408 [藏格控股])    撤销特别处理
# Equity(603665 [康隆达])        新上市
# Equity(600723 [首商股份])       新上市
# Equity(002647 [民盛金科])       新上市
# Equity(000882 [华联股份])       新上市
# Equity(300314 [戴维医疗])       新上市
# Equity(600580 [卧龙电气])       新上市
# Equity(000016 [深康佳Ａ])       新上市
# Equity(000685 [中山公用])       新上市
# Equity(603598 [引力传媒])       新上市
# Equity(603101 [汇嘉时代])       新上市
# Equity(603938 [三孚股份])       新上市
# Equity(600760 [中航黑豹])    撤销特别处理
# Equity(600958 [东方证券])       新上市
# Equity(002218 [拓日新能])       新上市
# Equity(000968 [蓝焰控股])    撤销特别处理
# Equity(603993 [洛阳钼业])       新上市
# Equity(002718 [友邦吊顶])       新上市
# Equity(002745 [木林森])        新上市
# Equity(603859 [能科股份])       新上市
# Equity(600118 [中国卫星])       新上市
# Equity(002827 [高争民爆])       新上市
# Equity(002316 [键桥通讯])       新上市
# Equity(600459 [贵研铂业])       新上市
# Equity(002269 [美邦服饰])       新上市
# Equity(300222 [科大智能])       新上市
# Equity(601579 [会稽山])        新上市
# Equity(300087 [荃银高科])       新上市
#
# [341 rows x 1 columns]
#
#  2017-11-02 15:00:00+08:00
#                        treatment
# Equity(002732 [燕塘乳业])        新上市
# Equity(300120 [经纬电材])        新上市
# Equity(300322 [硕贝德])         新上市
# Equity(002714 [牧原股份])        新上市
# Equity(300010 [立思辰])         新上市
# Equity(601555 [东吴证券])        新上市
# Equity(002644 [佛慈制药])        新上市
# Equity(601789 [宁波建工])        新上市
# Equity(002009 [天奇股份])        新上市
# Equity(300367 [东方网力])        新上市
# Equity(300130 [新国都])         新上市
# Equity(600162 [香江控股])        新上市
# Equity(300286 [安科瑞])         新上市
# Equity(300471 [厚普股份])        新上市
# Equity(002799 [环球印务])        新上市
# Equity(002273 [水晶光电])        新上市
# Equity(300172 [中电环保])        新上市
# Equity(300015 [爱尔眼科])        新上市
# Equity(603227 [雪峰科技])        新上市
# Equity(601336 [新华保险])        新上市
# Equity(600859 [王府井])         新上市
# Equity(603458 [勘设股份])        新上市
# Equity(601186 [中国铁建])        新上市
# Equity(000861 [海印股份])        新上市
# Equity(000811 [冰轮环境])        新上市
# Equity(300548 [博创科技])        新上市
# Equity(300517 [海波重科])        新上市
# Equity(002549 [凯美特气])        新上市
# Equity(600533 [栖霞建设])        新上市
# Equity(002419 [天虹股份])        新上市
# ...                          ...
# Equity(002632 [道明光学])        新上市
# Equity(002557 [洽洽食品])        新上市
# Equity(000421 [南京公用])        新上市
# Equity(000555 [神州信息])     撤销特别处理
# Equity(300406 [九强生物])        新上市
# Equity(002012 [凯恩股份])        新上市
# Equity(603330 [上海天洋])        新上市
# Equity(600156 [华升股份])     撤销特别处理
# Equity(600479 [千金药业])        新上市
# Equity(600114 [东睦股份])        新上市
# Equity(002638 [勤上股份])        新上市
# Equity(601952 [苏垦农发])        新上市
# Equity(600702 [沱牌舍得])        新上市
# Equity(300700 [岱勒新材])        新上市
# Equity(603801 [志邦股份])        新上市
# Equity(000966 [长源电力])        新上市
# Equity(002721 [金一文化])        新上市
# Equity(002735 [王子新材])        新上市
# Equity(603839 [安正时尚])        新上市
# Equity(002231 [奥维通信])        新上市
# Equity(000582 [北部湾港])        新上市
# Equity(600689 [上海三毛])     撤销特别处理
# Equity(600657 [信达地产])     撤销特别处理
# Equity(603355 [莱克电气])        新上市
# Equity(600112 [*ST天成])    实施特别处理
# Equity(000936 [华西股份])        新上市
# Equity(600854 [春兰股份])     撤销特别处理
# Equity(300293 [蓝英装备])        新上市
# Equity(600210 [紫江企业])        新上市
# Equity(600281 [太化股份])     撤销特别处理
#
# [342 rows x 1 columns]
#
#  2017-11-03 15:00:00+08:00
#                        treatment
# Equity(300393 [中来股份])        新上市
# Equity(600351 [亚宝药业])        新上市
# Equity(601375 [中原证券])        新上市
# Equity(300213 [佳讯飞鸿])        新上市
# Equity(000818 [方大化工])     撤销特别处理
# Equity(300555 [路通视信])        新上市
# Equity(600099 [林海股份])        新上市
# Equity(002498 [汉缆股份])        新上市
# Equity(000622 [恒立实业])     撤销特别处理
# Equity(300478 [杭州高新])        新上市
# Equity(000008 [神州高铁])     撤销特别处理
# Equity(600586 [金晶科技])        新上市
# Equity(002837 [英维克])         新上市
# Equity(000530 [大冷股份])        新上市
# Equity(000682 [东方电子])     撤销特别处理
# Equity(000905 [厦门港务])        新上市
# Equity(002370 [亚太药业])        新上市
# Equity(000551 [创元科技])        新上市
# Equity(600679 [上海凤凰])        新上市
# Equity(300216 [千山药机])        新上市
# Equity(002168 [深圳惠程])        新上市
# Equity(002755 [东方新星])        新上市
# Equity(600300 [维维股份])        新上市
# Equity(600861 [北京城乡])        新上市
# Equity(603829 [洛凯股份])        新上市
# Equity(000995 [皇台酒业])     撤销特别处理
# Equity(300229 [拓尔思])         新上市
# Equity(600110 [诺德股份])        新上市
# Equity(300026 [红日药业])        新上市
# Equity(300044 [赛为智能])        新上市
# ...                          ...
# Equity(600037 [歌华有线])        新上市
# Equity(600765 [中航重机])        新上市
# Equity(000886 [海南高速])        新上市
# Equity(600152 [维科精华])        新上市
# Equity(300092 [科新机电])        新上市
# Equity(600605 [汇通能源])        新上市
# Equity(002636 [金安国纪])        新上市
# Equity(600610 [中毅达])      撤销特别处理
# Equity(603023 [威帝股份])        新上市
# Equity(600150 [中国船舶])     撤销特别处理
# Equity(002863 [今飞凯达])        新上市
# Equity(300187 [永清环保])        新上市
# Equity(000948 [南天信息])        新上市
# Equity(601882 [海天精工])        新上市
# Equity(600708 [光明地产])        新上市
# Equity(601218 [吉鑫科技])        新上市
# Equity(000525 [红 太 阳])       新上市
# Equity(300266 [兴源环境])        新上市
# Equity(600289 [亿阳信通])        新上市
# Equity(300539 [横河模具])        新上市
# Equity(603178 [圣龙股份])        新上市
# Equity(000726 [鲁 泰Ａ])        新上市
# Equity(600746 [江苏索普])        新上市
# Equity(300559 [佳发安泰])        新上市
# Equity(601618 [中国中冶])        新上市
# Equity(300670 [大烨智能])        新上市
# Equity(000913 [钱江摩托])     撤销特别处理
# Equity(600358 [国旅联合])     撤销特别处理
# Equity(002082 [栋梁新材])        新上市
# Equity(002406 [远东传动])        新上市
#
# [342 rows x 1 columns]
#
#  2017-11-06 15:00:00+08:00
#                        treatment
# Equity(002495 [佳隆股份])        新上市
# Equity(300514 [友讯达])         新上市
# Equity(002463 [沪电股份])        新上市
# Equity(601006 [大秦铁路])        新上市
# Equity(600531 [豫光金铅])        新上市
# Equity(002158 [汉钟精机])        新上市
# Equity(000972 [*ST中基])    实施特别处理
# Equity(000598 [兴蓉环境])     撤销特别处理
# Equity(600071 [凤凰光学])     撤销特别处理
# Equity(601011 [宝泰隆])         新上市
# Equity(002775 [文科园林])        新上市
# Equity(002090 [金智科技])        新上市
# Equity(002498 [汉缆股份])        新上市
# Equity(600528 [中铁工业])        新上市
# Equity(300593 [新雷能])         新上市
# Equity(000697 [炼石有色])     撤销特别处理
# Equity(002161 [远 望 谷])       新上市
# Equity(600308 [华泰股份])        新上市
# Equity(300180 [华峰超纤])        新上市
# Equity(000957 [中通客车])        新上市
# Equity(600428 [中远海特])        新上市
# Equity(I399003 [成份B指])   unknown
# Equity(000802 [北京文化])     撤销特别处理
# Equity(603011 [合锻智能])        新上市
# Equity(600246 [万通地产])        新上市
# Equity(002638 [勤上股份])        新上市
# Equity(002275 [桂林三金])        新上市
# Equity(300324 [旋极信息])        新上市
# Equity(600618 [氯碱化工])        新上市
# Equity(002138 [顺络电子])        新上市
# ...                          ...
# Equity(002626 [金达威])         新上市
# Equity(600356 [恒丰纸业])        新上市
# Equity(000953 [*ST河化])    实施特别处理
# Equity(000908 [景峰医药])     撤销特别处理
# Equity(300340 [科恒股份])        新上市
# Equity(603628 [清源股份])        新上市
# Equity(000533 [万 家 乐])    撤销特别处理
# Equity(300061 [康旗股份])        新上市
# Equity(603696 [安记食品])        新上市
# Equity(002441 [众业达])         新上市
# Equity(601958 [金钼股份])        新上市
# Equity(603969 [银龙股份])        新上市
# Equity(300259 [新天科技])        新上市
# Equity(601336 [新华保险])        新上市
# Equity(000766 [通化金马])     撤销特别处理
# Equity(000933 [神火股份])     撤销特别处理
# Equity(600965 [福成股份])        新上市
# Equity(000050 [深天马Ａ])        新上市
# Equity(603022 [新通联])         新上市
# Equity(603716 [塞力斯])         新上市
# Equity(601212 [白银有色])        新上市
# Equity(603818 [曲美家居])        新上市
# Equity(600143 [金发科技])        新上市
# Equity(300211 [亿通科技])        新上市
# Equity(600262 [北方股份])        新上市
# Equity(600031 [三一重工])        新上市
# Equity(601188 [龙江交通])        新上市
# Equity(002076 [雪 莱 特])       新上市
# Equity(601166 [兴业银行])        新上市
# Equity(600006 [东风汽车])        新上市
#
# [342 rows x 1 columns]
#
#  2017-11-07 15:00:00+08:00
#                        treatment
# Equity(000059 [华锦股份])     撤销特别处理
# Equity(000517 [荣安地产])     撤销特别处理
# Equity(000978 [桂林旅游])        新上市
# Equity(002366 [台海核电])        新上市
# Equity(600585 [海螺水泥])        新上市
# Equity(002619 [艾格拉斯])        新上市
# Equity(000732 [泰禾集团])     撤销特别处理
# Equity(300412 [迦南科技])        新上市
# Equity(002725 [跃岭股份])        新上市
# Equity(300293 [蓝英装备])        新上市
# Equity(300515 [三德科技])        新上市
# Equity(603311 [金海环境])        新上市
# Equity(002160 [常铝股份])     撤销特别处理
# Equity(600138 [中青旅])         新上市
# Equity(600834 [申通地铁])        新上市
# Equity(300470 [日机密封])        新上市
# Equity(300264 [佳创视讯])        新上市
# Equity(300330 [华虹计通])        新上市
# Equity(002679 [福建金森])        新上市
# Equity(000671 [阳 光 城])       新上市
# Equity(601258 [庞大集团])        新上市
# Equity(600313 [农发种业])     撤销特别处理
# Equity(600322 [天房发展])        新上市
# Equity(600104 [上汽集团])        新上市
# Equity(300535 [达威股份])        新上市
# Equity(000762 [西藏矿业])        新上市
# Equity(000587 [金洲慈航])     撤销特别处理
# Equity(002210 [飞马国际])        新上市
# Equity(000988 [华工科技])        新上市
# Equity(000032 [深桑达Ａ])        新上市
# ...                          ...
# Equity(000820 [神雾节能])     撤销特别处理
# Equity(002587 [奥拓电子])        新上市
# Equity(600691 [阳煤化工])     撤销特别处理
# Equity(002031 [巨轮智能])        新上市
# Equity(600594 [益佰制药])        新上市
# Equity(300253 [卫宁健康])        新上市
# Equity(600573 [惠泉啤酒])        新上市
# Equity(603103 [横店影视])        新上市
# Equity(601666 [平煤股份])        新上市
# Equity(002606 [大连电瓷])        新上市
# Equity(300165 [天瑞仪器])        新上市
# Equity(603126 [中材节能])        新上市
# Equity(600868 [梅雁吉祥])     撤销特别处理
# Equity(002142 [宁波银行])        新上市
# Equity(002193 [如意集团])        新上市
# Equity(002289 [宇顺电子])     撤销特别处理
# Equity(002658 [雪迪龙])         新上市
# Equity(600197 [伊力特])         新上市
# Equity(000930 [中粮生化])        新上市
# Equity(300351 [永贵电器])        新上市
# Equity(300621 [维业股份])        新上市
# Equity(603305 [旭升股份])        新上市
# Equity(603618 [杭电股份])        新上市
# Equity(000922 [*ST佳电])    实施特别处理
# Equity(600538 [国发股份])     撤销特别处理
# Equity(601328 [交通银行])        新上市
# Equity(300329 [海伦钢琴])        新上市
# Equity(300695 [兆丰股份])        新上市
# Equity(300097 [智云股份])        新上市
# Equity(300081 [恒信东方])        新上市
#
# [342 rows x 1 columns]
#
#  2017-11-08 15:00:00+08:00
#                        treatment
# Equity(601258 [庞大集团])        新上市
# Equity(603456 [九洲药业])        新上市
# Equity(I000016 [上证50])   unknown
# Equity(600819 [耀皮玻璃])        新上市
# Equity(000930 [中粮生化])        新上市
# Equity(300317 [珈伟股份])        新上市
# Equity(002640 [跨境通])         新上市
# Equity(002197 [证通电子])        新上市
# Equity(000012 [南 玻Ａ])        新上市
# Equity(603335 [迪生力])         新上市
# Equity(601168 [西部矿业])        新上市
# Equity(300210 [森远股份])        新上市
# Equity(300001 [特锐德])         新上市
# Equity(000627 [天茂集团])        新上市
# Equity(603116 [红蜻蜓])         新上市
# Equity(600693 [东百集团])        新上市
# Equity(000046 [泛海控股])        新上市
# Equity(300628 [亿联网络])        新上市
# Equity(600279 [重庆港九])        新上市
# Equity(000961 [中南建设])        新上市
# Equity(002862 [实丰文化])        新上市
# Equity(600853 [龙建股份])     撤销特别处理
# Equity(002644 [佛慈制药])        新上市
# Equity(002259 [升达林业])        新上市
# Equity(300645 [正元智慧])        新上市
# Equity(600781 [辅仁药业])     撤销特别处理
# Equity(300232 [洲明科技])        新上市
# Equity(603568 [伟明环保])        新上市
# Equity(600965 [福成股份])        新上市
# Equity(000766 [通化金马])     撤销特别处理
# ...                          ...
# Equity(300211 [亿通科技])        新上市
# Equity(601890 [亚星锚链])        新上市
# Equity(600067 [冠城大通])        新上市
# Equity(002449 [国星光电])        新上市
# Equity(600749 [西藏旅游])     撤销特别处理
# Equity(600710 [ST常林])       恢复上市
# Equity(600220 [江苏阳光])        新上市
# Equity(600232 [金鹰股份])        新上市
# Equity(601882 [海天精工])        新上市
# Equity(002589 [瑞康医药])        新上市
# Equity(600720 [祁连山])         新上市
# Equity(002454 [松芝股份])        新上市
# Equity(002296 [辉煌科技])        新上市
# Equity(002807 [江阴银行])        新上市
# Equity(600568 [中珠医疗])     撤销特别处理
# Equity(000150 [宜华健康])     撤销特别处理
# Equity(601377 [兴业证券])        新上市
# Equity(600551 [时代出版])        新上市
# Equity(300057 [万顺股份])        新上市
# Equity(002477 [雏鹰农牧])        新上市
# Equity(002330 [得利斯])         新上市
# Equity(600573 [惠泉啤酒])        新上市
# Equity(002266 [浙富控股])        新上市
# Equity(300110 [华仁药业])        新上市
# Equity(300485 [赛升药业])        新上市
# Equity(600184 [光电股份])        新上市
# Equity(600197 [伊力特])         新上市
# Equity(600879 [航天电子])        新上市
# Equity(601333 [广深铁路])        新上市
# Equity(600761 [安徽合力])        新上市
#
# [342 rows x 1 columns]
#
#  2017-11-09 15:00:00+08:00
#                        treatment
# Equity(002863 [今飞凯达])        新上市
# Equity(300371 [汇中股份])        新上市
# Equity(600403 [*ST大有])    实施特别处理
# Equity(002666 [德联集团])        新上市
# Equity(300441 [鲍斯股份])        新上市
# Equity(600346 [恒力股份])     撤销特别处理
# Equity(002753 [永东股份])        新上市
# Equity(002414 [高德红外])        新上市
# Equity(002395 [双象股份])        新上市
# Equity(603618 [杭电股份])        新上市
# Equity(300417 [南华仪器])        新上市
# Equity(603218 [日月股份])        新上市
# Equity(300202 [聚龙股份])        新上市
# Equity(002642 [荣之联])         新上市
# Equity(600639 [浦东金桥])        新上市
# Equity(300318 [博晖创新])        新上市
# Equity(002101 [广东鸿图])        新上市
# Equity(002178 [延华智能])        新上市
# Equity(000518 [四环生物])     撤销特别处理
# Equity(002781 [奇信股份])        新上市
# Equity(603111 [康尼机电])        新上市
# Equity(600796 [钱江生化])        新上市
# Equity(002526 [山东矿机])        新上市
# Equity(002634 [棒杰股份])        新上市
# Equity(300600 [瑞特股份])        新上市
# Equity(300266 [兴源环境])        新上市
# Equity(000416 [民生控股])     撤销特别处理
# Equity(600525 [长园集团])        新上市
# Equity(600598 [北大荒])      撤销特别处理
# Equity(002793 [东音股份])        新上市
# ...                          ...
# Equity(603556 [海兴电力])        新上市
# Equity(600338 [西藏珠峰])     撤销特别处理
# Equity(300043 [星辉娱乐])        新上市
# Equity(000630 [铜陵有色])        新上市
# Equity(600505 [西昌电力])        新上市
# Equity(600388 [龙净环保])        新上市
# Equity(002824 [和胜股份])        新上市
# Equity(002690 [美亚光电])        新上市
# Equity(300345 [红宇新材])        新上市
# Equity(603869 [北部湾旅])        新上市
# Equity(600500 [中化国际])        新上市
# Equity(002590 [万安科技])        新上市
# Equity(002450 [康得新])         新上市
# Equity(300104 [乐视网])         新上市
# Equity(600643 [爱建集团])        新上市
# Equity(603936 [博敏电子])        新上市
# Equity(300416 [苏试试验])        新上市
# Equity(000099 [中信海直])        新上市
# Equity(300020 [银江股份])        新上市
# Equity(603308 [应流股份])        新上市
# Equity(002137 [麦达数字])        新上市
# Equity(601515 [东风股份])        新上市
# Equity(603928 [兴业股份])        新上市
# Equity(601669 [中国电建])        新上市
# Equity(002816 [和科达])         新上市
# Equity(002299 [圣农发展])        新上市
# Equity(603466 [风语筑])         新上市
# Equity(600538 [国发股份])     撤销特别处理
# Equity(600644 [乐山电力])     撤销特别处理
# Equity(600179 [安通控股])     撤销特别处理
#
# [342 rows x 1 columns]
#
#  2017-11-10 15:00:00+08:00
#                        treatment
# Equity(002880 [卫光生物])        新上市
# Equity(300508 [维宏股份])        新上市
# Equity(600569 [安阳钢铁])        新上市
# Equity(300398 [飞凯材料])        新上市
# Equity(600506 [香梨股份])     撤销特别处理
# Equity(002035 [华帝股份])        新上市
# Equity(300498 [温氏股份])        新上市
# Equity(000707 [双环科技])        新上市
# Equity(603017 [中衡设计])        新上市
# Equity(600155 [宝硕股份])     撤销特别处理
# Equity(603517 [绝味食品])        新上市
# Equity(000679 [大连友谊])        新上市
# Equity(600865 [百大集团])        新上市
# Equity(002259 [升达林业])        新上市
# Equity(600608 [*ST沪科])    实施特别处理
# Equity(000622 [恒立实业])     撤销特别处理
# Equity(603088 [宁波精达])        新上市
# Equity(603588 [高能环境])        新上市
# Equity(603600 [永艺股份])        新上市
# Equity(I000016 [上证50])   unknown
# Equity(002263 [大 东 南])       新上市
# Equity(600587 [新华医疗])        新上市
# Equity(600804 [鹏博士])         新上市
# Equity(000553 [沙隆达Ａ])        新上市
# Equity(600686 [金龙汽车])        新上市
# Equity(600356 [恒丰纸业])        新上市
# Equity(000868 [安凯客车])        新上市
# Equity(600552 [凯盛科技])     撤销特别处理
# Equity(600689 [上海三毛])     撤销特别处理
# Equity(300577 [开润股份])        新上市
# ...                          ...
# Equity(300616 [尚品宅配])        新上市
# Equity(603580 [艾艾精工])        新上市
# Equity(002750 [龙津药业])        新上市
# Equity(002466 [天齐锂业])        新上市
# Equity(300643 [万通智控])        新上市
# Equity(000998 [隆平高科])        新上市
# Equity(603060 [国检集团])        新上市
# Equity(600323 [瀚蓝环境])        新上市
# Equity(600228 [*ST昌九])    实施特别处理
# Equity(300409 [道氏技术])        新上市
# Equity(300545 [联得装备])        新上市
# Equity(000430 [张家界])      撤销特别处理
# Equity(300525 [博思软件])        新上市
# Equity(002863 [今飞凯达])        新上市
# Equity(002301 [齐心集团])        新上市
# Equity(603969 [银龙股份])        新上市
# Equity(300653 [正海生物])        新上市
# Equity(002667 [鞍重股份])        新上市
# Equity(000088 [盐 田 港])       新上市
# Equity(603456 [九洲药业])        新上市
# Equity(002827 [高争民爆])        新上市
# Equity(600763 [通策医疗])     撤销特别处理
# Equity(002460 [赣锋锂业])        新上市
# Equity(000676 [智度股份])     撤销特别处理
# Equity(600270 [外运发展])        新上市
# Equity(002094 [青岛金王])        新上市
# Equity(600727 [鲁北化工])     撤销特别处理
# Equity(000631 [顺发恒业])       恢复上市
# Equity(601558 [*ST锐电])    实施特别处理
# Equity(603889 [新澳股份])        新上市
#
# [343 rows x 1 columns]
#
#  2017-11-13 15:00:00+08:00
#                        treatment
# Equity(600612 [老凤祥])         新上市
# Equity(002629 [仁智股份])        新上市
# Equity(002356 [赫美集团])        新上市
# Equity(603229 [奥翔药业])        新上市
# Equity(002618 [丹邦科技])        新上市
# Equity(601500 [通用股份])        新上市
# Equity(300160 [秀强股份])        未上市
# Equity(600119 [长江投资])        新上市
# Equity(000895 [双汇发展])        新上市
# Equity(300282 [汇冠股份])        新上市
# Equity(300015 [爱尔眼科])        新上市
# Equity(601579 [会稽山])         新上市
# Equity(300204 [舒泰神])         新上市
# Equity(002245 [澳洋顺昌])        新上市
# Equity(002058 [威 尔 泰])       新上市
# Equity(603507 [振江股份])        新上市
# Equity(300005 [探路者])         新上市
# Equity(002601 [龙蟒佰利])        新上市
# Equity(601969 [海南矿业])        新上市
# Equity(600300 [维维股份])        新上市
# Equity(002562 [兄弟科技])        新上市
# Equity(000151 [中成股份])        新上市
# Equity(603690 [至纯科技])        新上市
# Equity(300669 [沪宁股份])        新上市
# Equity(300209 [天泽信息])        新上市
# Equity(600107 [美尔雅])         新上市
# Equity(603806 [福斯特])         新上市
# Equity(601789 [宁波建工])        新上市
# Equity(600149 [*ST坊展])    实施特别处理
# Equity(600115 [东方航空])     撤销特别处理
# ...                          ...
# Equity(603701 [德宏股份])        新上市
# Equity(600346 [恒力股份])     撤销特别处理
# Equity(600051 [宁波联合])        新上市
# Equity(601336 [新华保险])        新上市
# Equity(300265 [通光线缆])        新上市
# Equity(600365 [通葡股份])     撤销特别处理
# Equity(002063 [远光软件])        新上市
# Equity(300111 [向日葵])         新上市
# Equity(603889 [新澳股份])        新上市
# Equity(300350 [华鹏飞])         新上市
# Equity(300055 [万邦达])         新上市
# Equity(300567 [精测电子])        新上市
# Equity(002689 [远大智能])        新上市
# Equity(600184 [光电股份])        新上市
# Equity(300385 [雪浪环境])        新上市
# Equity(000539 [粤电力Ａ])        新上市
# Equity(300660 [江苏雷利])        新上市
# Equity(000788 [北大医药])     撤销特别处理
# Equity(600400 [红豆股份])        新上市
# Equity(600573 [惠泉啤酒])        新上市
# Equity(600724 [宁波富达])        新上市
# Equity(603060 [国检集团])        新上市
# Equity(002766 [索菱股份])        新上市
# Equity(002831 [裕同科技])        新上市
# Equity(000518 [四环生物])     撤销特别处理
# Equity(002193 [如意集团])        新上市
# Equity(300030 [阳普医疗])        新上市
# Equity(603880 [南卫股份])        新上市
# Equity(002309 [中利集团])        新上市
# Equity(600004 [白云机场])        新上市
#
# [343 rows x 1 columns]
#
#  2017-11-14 15:00:00+08:00
#                        treatment
# Equity(300077 [国民技术])        新上市
# Equity(601108 [财通证券])        新上市
# Equity(000525 [红 太 阳])       新上市
# Equity(002042 [华孚时尚])        新上市
# Equity(600236 [桂冠电力])        新上市
# Equity(000966 [长源电力])        新上市
# Equity(002255 [海陆重工])        新上市
# Equity(601038 [一拖股份])        新上市
# Equity(601369 [陕鼓动力])        新上市
# Equity(603991 [至正股份])        新上市
# Equity(603803 [瑞斯康达])        新上市
# Equity(300170 [汉得信息])        新上市
# Equity(600406 [国电南瑞])        新上市
# Equity(300054 [鼎龙股份])        新上市
# Equity(000034 [神州数码])     撤销特别处理
# Equity(300593 [新雷能])         新上市
# Equity(603556 [海兴电力])        新上市
# Equity(300636 [同和药业])        新上市
# Equity(300427 [红相电力])        新上市
# Equity(603933 [睿能科技])        新上市
# Equity(300240 [飞力达])         新上市
# Equity(601288 [农业银行])        新上市
# Equity(600419 [天润乳业])     撤销特别处理
# Equity(002224 [三 力 士])       新上市
# Equity(600030 [中信证券])        新上市
# Equity(002276 [万马股份])        新上市
# Equity(000523 [广州浪奇])        新上市
# Equity(603677 [奇精机械])        新上市
# Equity(600661 [新南洋])         新上市
# Equity(300247 [乐金健康])        新上市
# ...                          ...
# Equity(I000002 [A股指数])   unknown
# Equity(600391 [航发科技])        新上市
# Equity(300546 [雄帝科技])        新上市
# Equity(000703 [恒逸石化])     撤销特别处理
# Equity(002626 [金达威])         新上市
# Equity(600329 [中新药业])     撤销特别处理
# Equity(601799 [星宇股份])        新上市
# Equity(300058 [蓝色光标])        新上市
# Equity(600790 [轻纺城])         新上市
# Equity(300269 [联建光电])        新上市
# Equity(300276 [三丰智能])        新上市
# Equity(600122 [宏图高科])        新上市
# Equity(000928 [中钢国际])     撤销特别处理
# Equity(603906 [龙蟠科技])        新上市
# Equity(603628 [清源股份])        新上市
# Equity(300409 [道氏技术])        新上市
# Equity(002427 [尤夫股份])        新上市
# Equity(300169 [天晟新材])        新上市
# Equity(002598 [山东章鼓])        新上市
# Equity(300417 [南华仪器])        新上市
# Equity(002031 [巨轮智能])        新上市
# Equity(002865 [钧达股份])        新上市
# Equity(002172 [澳洋科技])        新上市
# Equity(002353 [杰瑞股份])        新上市
# Equity(300156 [神雾环保])        新上市
# Equity(600018 [上港集团])       换股上市
# Equity(002186 [全 聚 德])       新上市
# Equity(002860 [星帅尔])         新上市
# Equity(600629 [华建集团])     撤销特别处理
# Equity(002328 [新朋股份])        新上市
#
# [343 rows x 1 columns]
#
#  2017-11-15 15:00:00+08:00
#                        treatment
# Equity(300568 [星源材质])        新上市
# Equity(603919 [金徽酒])         新上市
# Equity(603900 [通灵珠宝])        新上市
# Equity(600518 [康美药业])        新上市
# Equity(603303 [得邦照明])        新上市
# Equity(600592 [龙溪股份])        新上市
# Equity(000598 [兴蓉环境])     撤销特别处理
# Equity(002341 [新纶科技])        新上市
# Equity(603527 [众源新材])        新上市
# Equity(603868 [飞科电器])        新上市
# Equity(000993 [闽东电力])     撤销特别处理
# Equity(601028 [玉龙股份])        新上市
# Equity(300292 [吴通控股])        新上市
# Equity(300655 [晶瑞股份])        新上市
# Equity(000927 [一汽夏利])     撤销特别处理
# Equity(002693 [双成药业])        新上市
# Equity(300176 [鸿特精密])        新上市
# Equity(603906 [龙蟠科技])        新上市
# Equity(601811 [新华文轩])        新上市
# Equity(300247 [乐金健康])        新上市
# Equity(300038 [梅泰诺])         新上市
# Equity(603322 [超讯通信])        新上市
# Equity(600429 [三元股份])     撤销特别处理
# Equity(600747 [*ST大控])    实施特别处理
# Equity(002358 [森源电气])        新上市
# Equity(600094 [大名城])      撤销特别处理
# Equity(603181 [皇马科技])        新上市
# Equity(600867 [通化东宝])        新上市
# Equity(002132 [恒星科技])        新上市
# Equity(002817 [黄山胶囊])        新上市
# ...                          ...
# Equity(002469 [三维工程])        新上市
# Equity(600275 [*ST昌鱼])    实施特别处理
# Equity(603611 [诺力股份])        新上市
# Equity(300305 [裕兴股份])        新上市
# Equity(000899 [赣能股份])     撤销特别处理
# Equity(300628 [亿联网络])        新上市
# Equity(000153 [丰原药业])        新上市
# Equity(300415 [伊之密])         新上市
# Equity(002518 [科士达])         新上市
# Equity(000700 [模塑科技])        新上市
# Equity(002264 [新 华 都])       新上市
# Equity(600143 [金发科技])        新上市
# Equity(600870 [厦华电子])     撤销特别处理
# Equity(600321 [正源股份])        新上市
# Equity(300221 [银禧科技])        新上市
# Equity(600826 [兰生股份])        新上市
# Equity(603638 [艾迪精密])        新上市
# Equity(000807 [云铝股份])        新上市
# Equity(600300 [维维股份])        新上市
# Equity(002254 [泰和新材])        新上市
# Equity(601952 [苏垦农发])        新上市
# Equity(300397 [天和防务])        新上市
# Equity(002746 [仙坛股份])        新上市
# Equity(300423 [鲁亿通])         新上市
# Equity(002517 [恺英网络])        新上市
# Equity(000150 [宜华健康])     撤销特别处理
# Equity(600481 [双良节能])        新上市
# Equity(000957 [中通客车])        新上市
# Equity(603007 [花王股份])        新上市
# Equity(603197 [保隆科技])        新上市
#
# [343 rows x 1 columns]
#
#  2017-11-16 15:00:00+08:00
#                        treatment
# Equity(000523 [广州浪奇])        新上市
# Equity(600438 [通威股份])        新上市
# Equity(600403 [*ST大有])    实施特别处理
# Equity(002421 [达实智能])        新上市
# Equity(603089 [正裕工业])        新上市
# Equity(600288 [大恒科技])        新上市
# Equity(002357 [富临运业])        新上市
# Equity(002853 [皮阿诺])         新上市
# Equity(300286 [安科瑞])         新上市
# Equity(603779 [威龙股份])        新上市
# Equity(600436 [片仔癀])         新上市
# Equity(600358 [国旅联合])     撤销特别处理
# Equity(000831 [五矿稀土])     撤销特别处理
# Equity(603668 [天马科技])        新上市
# Equity(300470 [日机密封])        新上市
# Equity(002150 [通润装备])        新上市
# Equity(600321 [正源股份])        新上市
# Equity(603567 [珍宝岛])         新上市
# Equity(603958 [哈森股份])        新上市
# Equity(002485 [希努尔])         新上市
# Equity(300692 [中环环保])        新上市
# Equity(600306 [商业城])      撤销特别处理
# Equity(002206 [海 利 得])       新上市
# Equity(000029 [深深房Ａ])        新上市
# Equity(300081 [恒信东方])        新上市
# Equity(600814 [杭州解百])        新上市
# Equity(002384 [东山精密])        新上市
# Equity(600316 [洪都航空])        新上市
# Equity(000620 [新华联])        恢复上市
# Equity(300700 [岱勒新材])        新上市
# ...                          ...
# Equity(002373 [千方科技])     撤销特别处理
# Equity(603628 [清源股份])        新上市
# Equity(601877 [正泰电器])        新上市
# Equity(300318 [博晖创新])        新上市
# Equity(600498 [烽火通信])        新上市
# Equity(300166 [东方国信])        新上市
# Equity(603730 [岱美股份])        新上市
# Equity(300150 [世纪瑞尔])        新上市
# Equity(600376 [首开股份])        新上市
# Equity(002412 [汉森制药])        新上市
# Equity(002314 [南山控股])        新上市
# Equity(600489 [中金黄金])        新上市
# Equity(600068 [葛洲坝])         新上市
# Equity(603223 [恒通股份])        新上市
# Equity(300255 [常山药业])        新上市
# Equity(603311 [金海环境])        新上市
# Equity(600035 [楚天高速])        新上市
# Equity(300466 [赛摩电气])        新上市
# Equity(603200 [上海洗霸])        新上市
# Equity(300430 [诚益通])         新上市
# Equity(002577 [雷柏科技])        新上市
# Equity(000818 [方大化工])     撤销特别处理
# Equity(000795 [英洛华])         新上市
# Equity(601006 [大秦铁路])        新上市
# Equity(002490 [*ST墨龙])    实施特别处理
# Equity(002423 [中原特钢])     撤销特别处理
# Equity(600420 [现代制药])        新上市
# Equity(000799 [酒鬼酒])      撤销特别处理
# Equity(300671 [富满电子])        新上市
# Equity(000519 [中兵红箭])        新上市
#
# [343 rows x 1 columns]
#
#  2017-11-17 15:00:00+08:00
#                        treatment
# Equity(601106 [*ST一重])    实施特别处理
# Equity(603677 [奇精机械])        新上市
# Equity(000518 [四环生物])     撤销特别处理
# Equity(002113 [天润数娱])     撤销特别处理
# Equity(000800 [一汽轿车])        新上市
# Equity(600847 [*ST万里])    实施特别处理
# Equity(600866 [星湖科技])     撤销特别处理
# Equity(000839 [中信国安])        新上市
# Equity(600078 [澄星股份])        新上市
# Equity(300142 [沃森生物])        新上市
# Equity(300534 [陇神戎发])        新上市
# Equity(603298 [杭叉集团])        新上市
# Equity(600278 [东方创业])        新上市
# Equity(603536 [惠发股份])        新上市
# Equity(603006 [联明股份])        新上市
# Equity(002307 [北新路桥])        新上市
# Equity(000976 [华铁股份])     撤销特别处理
# Equity(600355 [精伦电子])     撤销特别处理
# Equity(600557 [康缘药业])        新上市
# Equity(603166 [福达股份])        未上市
# Equity(600101 [明星电力])     撤销特别处理
# Equity(002495 [佳隆股份])        新上市
# Equity(000916 [华北高速])        新上市
# Equity(002306 [*ST云网])    实施特别处理
# Equity(600701 [工大高新])     撤销特别处理
# Equity(300648 [星云股份])        新上市
# Equity(002847 [盐津铺子])        新上市
# Equity(600094 [大名城])      撤销特别处理
# Equity(300062 [中能电气])        新上市
# Equity(002435 [长江润发])        新上市
# ...                          ...
# Equity(000936 [华西股份])        新上市
# Equity(002174 [游族网络])        新上市
# Equity(603626 [科森科技])        新上市
# Equity(002406 [远东传动])        新上市
# Equity(603079 [圣达生物])        新上市
# Equity(603725 [天安新材])        新上市
# Equity(300410 [正业科技])        新上市
# Equity(002269 [美邦服饰])        新上市
# Equity(603969 [银龙股份])        新上市
# Equity(603225 [新凤鸣])         新上市
# Equity(600246 [万通地产])        新上市
# Equity(600979 [广安爱众])        新上市
# Equity(300535 [达威股份])        新上市
# Equity(600418 [江淮汽车])        新上市
# Equity(600611 [大众交通])        新上市
# Equity(002751 [易尚展示])        新上市
# Equity(603963 [大理药业])        新上市
# Equity(002692 [睿康股份])        新上市
# Equity(000612 [焦作万方])        新上市
# Equity(000617 [中油资本])     撤销特别处理
# Equity(000605 [渤海股份])     撤销特别处理
# Equity(603990 [麦迪科技])        新上市
# Equity(300320 [海达股份])        新上市
# Equity(603658 [安图生物])        新上市
# Equity(600861 [北京城乡])        新上市
# Equity(300309 [吉艾科技])        新上市
# Equity(600353 [旭光股份])        新上市
# Equity(300140 [中环装备])        新上市
# Equity(002287 [奇正藏药])        新上市
# Equity(000551 [创元科技])        新上市
#
# [344 rows x 1 columns]
#
#  2017-11-20 15:00:00+08:00
#                        treatment
# Equity(000150 [宜华健康])     撤销特别处理
# Equity(002551 [尚荣医疗])        新上市
# Equity(600801 [华新水泥])        新上市
# Equity(603030 [全筑股份])        新上市
# Equity(002748 [世龙实业])        新上市
# Equity(600876 [洛阳玻璃])     撤销特别处理
# Equity(600588 [用友网络])        新上市
# Equity(002706 [良信电器])        新上市
# Equity(300367 [东方网力])        新上市
# Equity(600696 [*ST匹凸])    实施特别处理
# Equity(600279 [重庆港九])        新上市
# Equity(603729 [龙韵股份])        新上市
# Equity(300041 [回天新材])        新上市
# Equity(603556 [海兴电力])        新上市
# Equity(002090 [金智科技])        新上市
# Equity(000662 [天夏智慧])     撤销特别处理
# Equity(603990 [麦迪科技])        新上市
# Equity(000507 [珠海港])      撤销特别处理
# Equity(000030 [富奥股份])     撤销特别处理
# Equity(600600 [青岛啤酒])        新上市
# Equity(600803 [新奥股份])        新上市
# Equity(601168 [西部矿业])        新上市
# Equity(603637 [镇海股份])        新上市
# Equity(300699 [光威复材])        新上市
# Equity(300189 [神农基因])        新上市
# Equity(600644 [乐山电力])     撤销特别处理
# Equity(603605 [珀莱雅])         新上市
# Equity(002648 [卫星石化])        新上市
# Equity(601016 [节能风电])        新上市
# Equity(600182 [S佳通])      撤销特别处理
# ...                          ...
# Equity(300477 [合纵科技])        新上市
# Equity(002155 [湖南黄金])        新上市
# Equity(000039 [中集集团])        新上市
# Equity(002497 [雅化集团])        新上市
# Equity(000750 [国海证券])     撤销特别处理
# Equity(601677 [明泰铝业])        新上市
# Equity(600122 [宏图高科])        新上市
# Equity(I399001 [深证成指])   unknown
# Equity(300701 [森霸股份])        新上市
# Equity(601177 [杭齿前进])        新上市
# Equity(300405 [科隆股份])        新上市
# Equity(000631 [顺发恒业])       恢复上市
# Equity(601666 [平煤股份])        新上市
# Equity(300027 [华谊兄弟])        新上市
# Equity(002544 [杰赛科技])        新上市
# Equity(300074 [华平股份])        新上市
# Equity(002444 [巨星科技])        新上市
# Equity(601226 [华电重工])        新上市
# Equity(600133 [东湖高新])        新上市
# Equity(600406 [国电南瑞])        新上市
# Equity(600246 [万通地产])        新上市
# Equity(000705 [浙江震元])        新上市
# Equity(002233 [塔牌集团])        新上市
# Equity(002485 [希努尔])         新上市
# Equity(600301 [ST南化])     实施特别处理
# Equity(002397 [梦洁股份])        新上市
# Equity(300362 [天翔环境])        新上市
# Equity(000701 [厦门信达])        新上市
# Equity(600769 [祥龙电业])     撤销特别处理
# Equity(002751 [易尚展示])        新上市
#
# [344 rows x 1 columns]
#
#  2017-11-21 15:00:00+08:00
#                        treatment
# Equity(600258 [首旅酒店])        新上市
# Equity(603036 [如通股份])        新上市
# Equity(002463 [沪电股份])        新上市
# Equity(002400 [省广股份])        新上市
# Equity(600351 [亚宝药业])        新上市
# Equity(002431 [棕榈股份])        新上市
# Equity(002719 [麦趣尔])         新上市
# Equity(600667 [太极实业])        新上市
# Equity(603699 [纽威股份])        新上市
# Equity(002076 [雪 莱 特])       新上市
# Equity(000062 [深圳华强])        新上市
# Equity(002110 [三钢闽光])        新上市
# Equity(002380 [科远股份])        新上市
# Equity(600168 [武汉控股])        新上市
# Equity(300167 [迪威视讯])        新上市
# Equity(002511 [中顺洁柔])        新上市
# Equity(600647 [同达创业])     撤销特别处理
# Equity(600775 [南京熊猫])        新上市
# Equity(002825 [纳尔股份])        新上市
# Equity(600565 [迪马股份])        新上市
# Equity(300203 [聚光科技])        新上市
# Equity(600006 [东风汽车])        新上市
# Equity(600289 [亿阳信通])        新上市
# Equity(000996 [中国中期])        新上市
# Equity(600346 [恒力股份])     撤销特别处理
# Equity(002785 [万里石])         新上市
# Equity(600675 [中华企业])     撤销特别处理
# Equity(000156 [华数传媒])       恢复上市
# Equity(002728 [特一药业])        新上市
# Equity(603108 [润达医疗])        新上市
# ...                          ...
# Equity(300076 [GQY视讯])       新上市
# Equity(603600 [永艺股份])        新上市
# Equity(002084 [海鸥卫浴])        新上市
# Equity(002401 [中远海科])        新上市
# Equity(601878 [浙商证券])        新上市
# Equity(600741 [华域汽车])        新上市
# Equity(600609 [金杯汽车])     撤销特别处理
# Equity(002305 [南国置业])        新上市
# Equity(300403 [地尔汉宇])        新上市
# Equity(600163 [中闽能源])     撤销特别处理
# Equity(002474 [榕基软件])        新上市
# Equity(600975 [新五丰])         新上市
# Equity(600390 [五矿资本])     撤销特别处理
# Equity(I000001 [上证指数])   unknown
# Equity(002896 [中大力德])        新上市
# Equity(300471 [厚普股份])        新上市
# Equity(600636 [*ST爱富])    实施特别处理
# Equity(600150 [中国船舶])     撤销特别处理
# Equity(000525 [红 太 阳])       新上市
# Equity(002701 [奥瑞金])         新上市
# Equity(601369 [陕鼓动力])        新上市
# Equity(601908 [京运通])         新上市
# Equity(603027 [千禾味业])        新上市
# Equity(002456 [欧菲科技])        新上市
# Equity(002262 [恩华药业])        新上市
# Equity(603123 [翠微股份])        新上市
# Equity(000584 [哈工智能])        新上市
# Equity(002208 [合肥城建])        新上市
# Equity(300016 [北陆药业])        新上市
# Equity(002104 [恒宝股份])        新上市
#
# [344 rows x 1 columns]
#
#  2017-11-22 15:00:00+08:00
#                        treatment
# Equity(002172 [澳洋科技])        新上市
# Equity(002524 [光正集团])        新上市
# Equity(300440 [运达科技])        新上市
# Equity(002742 [三圣股份])        新上市
# Equity(002473 [*ST圣莱])    实施特别处理
# Equity(603139 [康惠制药])        新上市
# Equity(300556 [丝路视觉])        新上市
# Equity(601599 [鹿港文化])        新上市
# Equity(600426 [华鲁恒升])        新上市
# Equity(300133 [华策影视])        新上市
# Equity(300698 [万马科技])        新上市
# Equity(002422 [科伦药业])        新上市
# Equity(603997 [继峰股份])        新上市
# Equity(603311 [金海环境])        新上市
# Equity(002430 [杭氧股份])        新上市
# Equity(600375 [华菱星马])     撤销特别处理
# Equity(600069 [银鸽投资])     撤销特别处理
# Equity(000818 [方大化工])     撤销特别处理
# Equity(002731 [萃华珠宝])        新上市
# Equity(600256 [广汇能源])        新上市
# Equity(002829 [星网宇达])        新上市
# Equity(600011 [华能国际])        新上市
# Equity(300030 [阳普医疗])        新上市
# Equity(600278 [东方创业])        新上市
# Equity(600863 [内蒙华电])        新上市
# Equity(002600 [江粉磁材])        新上市
# Equity(300415 [伊之密])         新上市
# Equity(600155 [宝硕股份])     撤销特别处理
# Equity(601009 [南京银行])        新上市
# Equity(603029 [天鹅股份])        新上市
# ...                          ...
# Equity(300394 [天孚通信])        新上市
# Equity(600565 [迪马股份])        新上市
# Equity(600355 [精伦电子])     撤销特别处理
# Equity(300377 [赢时胜])         新上市
# Equity(600697 [欧亚集团])        新上市
# Equity(002237 [恒邦股份])        新上市
# Equity(600497 [驰宏锌锗])        新上市
# Equity(000585 [东北电气])     撤销特别处理
# Equity(300412 [迦南科技])        新上市
# Equity(000792 [盐湖股份])        新上市
# Equity(603031 [安德利])         新上市
# Equity(600871 [石化油服])     撤销特别处理
# Equity(002507 [涪陵榨菜])        新上市
# Equity(002420 [毅昌股份])        新上市
# Equity(600469 [风神股份])        新上市
# Equity(603008 [喜临门])         新上市
# Equity(300388 [国祯环保])        新上市
# Equity(000338 [潍柴动力])        新上市
# Equity(600613 [神奇制药])     撤销特别处理
# Equity(002139 [拓邦股份])        新上市
# Equity(600327 [大东方])         新上市
# Equity(000038 [深大通])      撤销特别处理
# Equity(300356 [光一科技])        新上市
# Equity(002634 [棒杰股份])        新上市
# Equity(000739 [普洛药业])        新上市
# Equity(603357 [设计总院])        新上市
# Equity(600435 [北方导航])        新上市
# Equity(600289 [亿阳信通])        新上市
# Equity(000573 [粤宏远Ａ])        新上市
# Equity(002025 [航天电器])        新上市
#
# [344 rows x 1 columns]
#
#  2017-11-23 15:00:00+08:00
#                        treatment
# Equity(000631 [顺发恒业])       恢复上市
# Equity(603990 [麦迪科技])        新上市
# Equity(002190 [成飞集成])        新上市
# Equity(600391 [航发科技])        新上市
# Equity(002619 [艾格拉斯])        新上市
# Equity(600854 [春兰股份])     撤销特别处理
# Equity(002249 [大洋电机])        新上市
# Equity(002276 [万马股份])        新上市
# Equity(600520 [文一科技])     撤销特别处理
# Equity(000017 [深中华A])     撤销特别处理
# Equity(300316 [晶盛机电])        新上市
# Equity(002096 [南岭民爆])        新上市
# Equity(300147 [香雪制药])        新上市
# Equity(002899 [英派斯])         新上市
# Equity(600681 [百川能源])     撤销特别处理
# Equity(002404 [嘉欣丝绸])        新上市
# Equity(603722 [阿科力])         新上市
# Equity(300229 [拓尔思])         新上市
# Equity(603006 [联明股份])        新上市
# Equity(002730 [电光科技])        新上市
# Equity(002898 [赛隆药业])        新上市
# Equity(603106 [恒银金融])        新上市
# Equity(603126 [中材节能])        新上市
# Equity(600405 [动力源])         新上市
# Equity(002759 [天际股份])        新上市
# Equity(601336 [新华保险])        新上市
# Equity(601601 [中国太保])        新上市
# Equity(000890 [法 尔 胜])       新上市
# Equity(000898 [鞍钢股份])     撤销特别处理
# Equity(002476 [宝莫股份])        新上市
# ...                          ...
# Equity(300246 [宝莱特])         新上市
# Equity(300193 [佳士科技])        新上市
# Equity(603566 [普莱柯])         新上市
# Equity(000856 [冀东装备])     撤销特别处理
# Equity(300327 [中颖电子])        新上市
# Equity(300376 [易事特])         新上市
# Equity(600777 [新潮能源])        新上市
# Equity(002481 [双塔食品])        新上市
# Equity(000750 [国海证券])     撤销特别处理
# Equity(002782 [可立克])         新上市
# Equity(600227 [赤天化])         新上市
# Equity(603519 [立霸股份])        新上市
# Equity(600984 [建设机械])     撤销特别处理
# Equity(600251 [冠农股份])        新上市
# Equity(002686 [亿利达])         新上市
# Equity(601009 [南京银行])        新上市
# Equity(002755 [东方新星])        新上市
# Equity(000762 [西藏矿业])        新上市
# Equity(600463 [空港股份])        新上市
# Equity(000929 [兰州黄河])        新上市
# Equity(002449 [国星光电])        新上市
# Equity(002287 [奇正藏药])        新上市
# Equity(600604 [市北高新])     撤销特别处理
# Equity(300387 [富邦股份])        新上市
# Equity(002143 [印纪传媒])        新上市
# Equity(300551 [古鳌科技])        新上市
# Equity(600630 [龙头股份])        新上市
# Equity(601001 [大同煤业])        新上市
# Equity(000939 [凯迪生态])        新上市
# Equity(300219 [鸿利智汇])        新上市
#
# [344 rows x 1 columns]
#
#  2017-11-24 15:00:00+08:00
#                        treatment
# Equity(300244 [迪安诊断])        新上市
# Equity(000807 [云铝股份])        新上市
# Equity(000063 [中兴通讯])        新上市
# Equity(300626 [华瑞股份])        新上市
# Equity(600017 [日照港])         新上市
# Equity(000608 [阳光股份])        新上市
# Equity(002011 [盾安环境])        新上市
# Equity(000016 [深康佳Ａ])        新上市
# Equity(002798 [帝王洁具])        新上市
# Equity(000739 [普洛药业])        新上市
# Equity(000627 [天茂集团])        新上市
# Equity(600096 [云天化])         新上市
# Equity(002438 [江苏神通])        新上市
# Equity(600568 [中珠医疗])     撤销特别处理
# Equity(300260 [新莱应材])        新上市
# Equity(002043 [兔 宝 宝])       新上市
# Equity(600962 [国投中鲁])     撤销特别处理
# Equity(000536 [华映科技])     撤销特别处理
# Equity(600822 [上海物贸])        新上市
# Equity(000615 [京汉股份])        新上市
# Equity(002561 [徐家汇])         新上市
# Equity(600560 [金自天正])        新上市
# Equity(002701 [奥瑞金])         新上市
# Equity(300471 [厚普股份])        新上市
# Equity(600127 [金健米业])        新上市
# Equity(000925 [众合科技])     撤销特别处理
# Equity(002848 [高斯贝尔])        新上市
# Equity(002164 [宁波东力])     撤销特别处理
# Equity(601801 [皖新传媒])        新上市
# Equity(002177 [御银股份])        新上市
# ...                          ...
# Equity(002861 [瀛通通讯])        新上市
# Equity(603586 [金麒麟])         新上市
# Equity(002109 [兴化股份])     撤销特别处理
# Equity(000408 [藏格控股])     撤销特别处理
# Equity(603901 [永创智能])        新上市
# Equity(600346 [恒力股份])     撤销特别处理
# Equity(300348 [长亮科技])        新上市
# Equity(300641 [正丹股份])        新上市
# Equity(000058 [深 赛 格])    撤销特别处理
# Equity(300238 [冠昊生物])        新上市
# Equity(002856 [美芝股份])        新上市
# Equity(002535 [林州重机])        新上市
# Equity(600319 [亚星化学])     撤销特别处理
# Equity(002397 [梦洁股份])        新上市
# Equity(002516 [旷达科技])        新上市
# Equity(002431 [棕榈股份])        新上市
# Equity(600594 [益佰制药])        新上市
# Equity(002395 [双象股份])        新上市
# Equity(000543 [皖能电力])        新上市
# Equity(600335 [国机汽车])     撤销特别处理
# Equity(002187 [广百股份])        新上市
# Equity(603278 [大业股份])        新上市
# Equity(300326 [凯利泰])         新上市
# Equity(300412 [迦南科技])        新上市
# Equity(600743 [华远地产])     撤销特别处理
# Equity(002792 [通宇通讯])        新上市
# Equity(600704 [物产中大])        新上市
# Equity(000563 [陕国投Ａ])        新上市
# Equity(601882 [海天精工])        新上市
# Equity(000571 [新大洲Ａ])     撤销特别处理
#
# [344 rows x 1 columns]
# [2017-12-09 16:28:19.108290] INFO: Performance: Simulated 18 trading days out of 18.
# [2017-12-09 16:28:19.108290] INFO: Performance: first open: 2017-11-01 01:31:00+00:00
# [2017-12-09 16:28:19.108290] INFO: Performance: last close: 2017-11-24 07:00:00+00:00
#                            algo_volatility  algorithm_period_return  alpha  \
# 2017-11-01 07:00:00+00:00              NaN                      0.0    NaN
# 2017-11-02 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-03 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-06 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-07 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-08 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-09 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-10 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-13 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-14 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-15 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-16 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-17 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-20 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-21 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-22 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-23 07:00:00+00:00              0.0                      0.0    0.0
# 2017-11-24 07:00:00+00:00              0.0                      0.0    0.0
#
#                            benchmark_period_return  benchmark_volatility  \
# 2017-11-01 07:00:00+00:00                -0.002520                   NaN
# 2017-11-02 07:00:00+00:00                -0.002392              0.029722
# 2017-11-03 07:00:00+00:00                -0.003499              0.021032
# 2017-11-06 07:00:00+00:00                 0.003537              0.067527
# 2017-11-07 07:00:00+00:00                 0.011862              0.078641
# 2017-11-08 07:00:00+00:00                 0.010305              0.074765
# 2017-11-09 07:00:00+00:00                 0.017266              0.074973
# 2017-11-10 07:00:00+00:00                 0.026254              0.078096
# 2017-11-13 07:00:00+00:00                 0.030288              0.073139
# 2017-11-14 07:00:00+00:00                 0.023119              0.086153
# 2017-11-15 07:00:00+00:00                 0.016710              0.091439
# 2017-11-16 07:00:00+00:00                 0.024532              0.091656
# 2017-11-17 07:00:00+00:00                 0.028485              0.088119
# 2017-11-20 07:00:00+00:00                 0.034221              0.085882
# 2017-11-21 07:00:00+00:00                 0.052657              0.104098
# 2017-11-22 07:00:00+00:00                 0.055120              0.100664
# 2017-11-23 07:00:00+00:00                 0.023880              0.160090
# 2017-11-24 07:00:00+00:00                 0.024331              0.155355
#
#                            beta  capital_used  ending_cash  ending_exposure  \
# 2017-11-01 07:00:00+00:00   NaN           0.0     100000.0              0.0
# 2017-11-02 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-03 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-06 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-07 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-08 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-09 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-10 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-13 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-14 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-15 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-16 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-17 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-20 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-21 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-22 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-23 07:00:00+00:00   0.0           0.0     100000.0              0.0
# 2017-11-24 07:00:00+00:00   0.0           0.0     100000.0              0.0
#
#                            ending_value          ...            \
# 2017-11-01 07:00:00+00:00           0.0          ...
# 2017-11-02 07:00:00+00:00           0.0          ...
# 2017-11-03 07:00:00+00:00           0.0          ...
# 2017-11-06 07:00:00+00:00           0.0          ...
# 2017-11-07 07:00:00+00:00           0.0          ...
# 2017-11-08 07:00:00+00:00           0.0          ...
# 2017-11-09 07:00:00+00:00           0.0          ...
# 2017-11-10 07:00:00+00:00           0.0          ...
# 2017-11-13 07:00:00+00:00           0.0          ...
# 2017-11-14 07:00:00+00:00           0.0          ...
# 2017-11-15 07:00:00+00:00           0.0          ...
# 2017-11-16 07:00:00+00:00           0.0          ...
# 2017-11-17 07:00:00+00:00           0.0          ...
# 2017-11-20 07:00:00+00:00           0.0          ...
# 2017-11-21 07:00:00+00:00           0.0          ...
# 2017-11-22 07:00:00+00:00           0.0          ...
# 2017-11-23 07:00:00+00:00           0.0          ...
# 2017-11-24 07:00:00+00:00           0.0          ...
#
#                            short_exposure  short_value  shorts_count  sortino  \
# 2017-11-01 07:00:00+00:00               0            0             0     None
# 2017-11-02 07:00:00+00:00               0            0             0     None
# 2017-11-03 07:00:00+00:00               0            0             0     None
# 2017-11-06 07:00:00+00:00               0            0             0     None
# 2017-11-07 07:00:00+00:00               0            0             0     None
# 2017-11-08 07:00:00+00:00               0            0             0     None
# 2017-11-09 07:00:00+00:00               0            0             0     None
# 2017-11-10 07:00:00+00:00               0            0             0     None
# 2017-11-13 07:00:00+00:00               0            0             0     None
# 2017-11-14 07:00:00+00:00               0            0             0     None
# 2017-11-15 07:00:00+00:00               0            0             0     None
# 2017-11-16 07:00:00+00:00               0            0             0     None
# 2017-11-17 07:00:00+00:00               0            0             0     None
# 2017-11-20 07:00:00+00:00               0            0             0     None
# 2017-11-21 07:00:00+00:00               0            0             0     None
# 2017-11-22 07:00:00+00:00               0            0             0     None
# 2017-11-23 07:00:00+00:00               0            0             0     None
# 2017-11-24 07:00:00+00:00               0            0             0     None
#
#                            starting_cash  starting_exposure  starting_value  \
# 2017-11-01 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-02 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-03 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-06 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-07 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-08 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-09 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-10 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-13 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-14 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-15 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-16 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-17 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-20 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-21 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-22 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-23 07:00:00+00:00       100000.0                0.0             0.0
# 2017-11-24 07:00:00+00:00       100000.0                0.0             0.0
#
#                            trading_days transactions treasury_period_return
# 2017-11-01 07:00:00+00:00             1           []                    0.0
# 2017-11-02 07:00:00+00:00             2           []                    0.0
# 2017-11-03 07:00:00+00:00             3           []                    0.0
# 2017-11-06 07:00:00+00:00             4           []                    0.0
# 2017-11-07 07:00:00+00:00             5           []                    0.0
# 2017-11-08 07:00:00+00:00             6           []                    0.0
# 2017-11-09 07:00:00+00:00             7           []                    0.0
# 2017-11-10 07:00:00+00:00             8           []                    0.0
# 2017-11-13 07:00:00+00:00             9           []                    0.0
# 2017-11-14 07:00:00+00:00            10           []                    0.0
# 2017-11-15 07:00:00+00:00            11           []                    0.0
# 2017-11-16 07:00:00+00:00            12           []                    0.0
# 2017-11-17 07:00:00+00:00            13           []                    0.0
# 2017-11-20 07:00:00+00:00            14           []                    0.0
# 2017-11-21 07:00:00+00:00            15           []                    0.0
# 2017-11-22 07:00:00+00:00            16           []                    0.0
# 2017-11-23 07:00:00+00:00            17           []                    0.0
# 2017-11-24 07:00:00+00:00            18           []                    0.0
#
# [18 rows x 37 columns]

# %% [markdown]
# <span class="girk">说明</span>：只要股票没有其他特别处理事项，其值一直为新上市。
