# %%
# %load_ext zipline

# %%
# %%zipline --start 2014-1-1 --end 2017-11-26 --capital-base 100000
#
# from zipline.pipeline import Pipeline, Fundamentals
#
# from zipline.pipeline.factors import CustomFactor
# from zipline.pipeline.data import USEquityPricing
# from zipline.api import attach_pipeline, pipeline_output
#
# from zipline.api import symbol, sid, get_datetime
#
#
# def make_pipeline():
#     return Pipeline(
#         columns = {
#             '股票简称':Fundamentals.short_name.latest,
#         },
#     )
#
# def initialize(context):
#     context.sids = [sid(33), sid(600696)]
#     context.year = 0
#     context.month = 0
#     attach_pipeline(make_pipeline(), 'example')
#
# def handle_data(context, data):
#     today = get_datetime('Asia/Shanghai')
#     output = pipeline_output('example')
#     # 只在月初显示
#     if (today.month != context.month) or (today.year != context.year):
#         print(today, output.reindex(context.sids))
#         context.month = today.month
#         context.year = today.year
# Out:
# [2017-12-09 16:30:42.748378] INFO: Loader: Read benchmark and treasury data for 000300 from 1990-10-31 to 2017-12-08
# 2014-01-02 15:00:00+08:00                         股票简称
# Equity(000033 [新都退])    新都酒店
# Equity(600696 [*ST匹凸])  多伦股份
# 2014-02-07 15:00:00+08:00                         股票简称
# Equity(000033 [新都退])    新都酒店
# Equity(600696 [*ST匹凸])  多伦股份
# 2014-03-03 15:00:00+08:00                         股票简称
# Equity(000033 [新都退])    新都酒店
# Equity(600696 [*ST匹凸])  多伦股份
# 2014-04-01 15:00:00+08:00                         股票简称
# Equity(000033 [新都退])    新都酒店
# Equity(600696 [*ST匹凸])  多伦股份
# 2014-05-05 15:00:00+08:00                         股票简称
# Equity(000033 [新都退])    新都酒店
# Equity(600696 [*ST匹凸])  多伦股份
# 2014-06-03 15:00:00+08:00                          股票简称
# Equity(000033 [新都退])    *ST新都
# Equity(600696 [*ST匹凸])   多伦股份
# 2014-07-01 15:00:00+08:00                          股票简称
# Equity(000033 [新都退])    *ST新都
# Equity(600696 [*ST匹凸])   多伦股份
# ...
