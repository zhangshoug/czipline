# %%
# %load_ext zipline

# %%
# %%zipline --start 2018-4-10 --end 2018-4-25
# from zipline.api import symbol, order, get_current_holdings, get_current_allocations
#
# STOCKS = ['000333','600771','600000']
#
# def initialize(context):
#     context.stocks = [symbol(x) for x in STOCKS]
#
# def handle_data(context, data):
#     for s in context.stocks:
#         order(s, 100000)
#     #print(get_current_holdings(context, data))
#     print(get_current_allocations(context, data))
# Out:
# Series([], dtype: float64)
# 美的集团(000333)    0.530122
# 浦发银行(600000)    0.119172
# 广誉远(600771)     0.505307
# dtype: float64
# 美的集团(000333)    1.036793
# 浦发银行(600000)    0.235462
# 广誉远(600771)     1.037793
# dtype: float64
# 美的集团(000333)    1.642778
# 浦发银行(600000)    0.374203
# 广誉远(600771)     1.581958
# dtype: float64
# 美的集团(000333)    2.221757
# 浦发银行(600000)    0.515391
# 广誉远(600771)     2.219972
# dtype: float64
# 美的集团(000333)    2.978758
# 浦发银行(600000)    0.689610
# 广誉远(600771)     2.877257
# dtype: float64
# 美的集团(000333)    3.466885
# 浦发银行(600000)    0.834528
# 广誉远(600771)     3.507438
# dtype: float64
# 美的集团(000333)    3.560910
# 浦发银行(600000)    0.814790
# 广誉远(600771)     3.400024
# dtype: float64
# 美的集团(000333)    3.930933
# 浦发银行(600000)    0.887901
# 广誉远(600771)     3.829218
# dtype: float64
# 美的集团(000333)    5.119253
# 浦发银行(600000)    1.140890
# 广誉远(600771)     4.701254
# dtype: float64
# 美的集团(000333)    4.050175
# 浦发银行(600000)    0.890963
# 广誉远(600771)     3.830838
# ...
