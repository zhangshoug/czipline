# %% [markdown]
# 历史数据

# %%
# %load_ext zipline

# %%
# %%zipline --start 2018-4-10 --end 2018-4-25
# from zipline.api import symbol, order, record
#
# def initialize(context):
#     pass
#
# def handle_data(context, data):
#     order(symbol('000333'), 10)
#     his = data[symbol('000333')]
#     record(收盘价=his.price,
#            成交量=his.volume,
#            总市值=his.tmv,
#            成交额=his.amount)
# Out:
# [2018-05-29 00:54:37.950292] INFO: zipline.finance.metrics.tracker: 模拟12个交易日
# 首个开盘时间: 2018-04-10 01:31:00+00:00
# 最后收盘时间: 2018-04-25 07:00:00+00:00
#                            algo_volatility  algorithm_period_return     alpha  \
# 2018-04-10 07:00:00+00:00              NaN             0.000000e+00       NaN
# 2018-04-11 07:00:00+00:00     3.085745e-07            -2.749000e-08 -0.000008
# 2018-04-12 07:00:00+00:00     1.029652e-05            -1.164425e-06 -0.000135
# 2018-04-13 07:00:00+00:00     1.024889e-05            -2.291085e-06 -0.000158
# 2018-04-16 07:00:00+00:00     3.004439e-05            -6.906980e-06 -0.000291
# 2018-04-17 07:00:00+00:00     2.918151e-05            -6.532925e-06 -0.000203
# 2018-04-18 07:00:00+00:00     3.895255e-05            -1.235829e-05 -0.000428
# 2018-04-19 07:00:00+00:00     1.113954e-04             4.654925e-06  0.000219
# 2018-04-20 07:00:00+00:00     1.046346e-04             3.438225e-06  0.000241
# ...

# %%
_.成交额
# Out:
# 2018-04-10 07:00:00+00:00    1.846470e+09
# 2018-04-11 07:00:00+00:00    2.476800e+09
# 2018-04-12 07:00:00+00:00    1.317120e+09
# 2018-04-13 07:00:00+00:00    1.241810e+09
# 2018-04-16 07:00:00+00:00    2.228860e+09
# 2018-04-17 07:00:00+00:00    1.555080e+09
# 2018-04-18 07:00:00+00:00    2.037850e+09
# 2018-04-19 07:00:00+00:00    2.193160e+09
# 2018-04-20 07:00:00+00:00    2.233310e+09
# 2018-04-23 07:00:00+00:00    1.499900e+09
# 2018-04-24 07:00:00+00:00    1.996950e+09
# 2018-04-25 07:00:00+00:00    1.916900e+09
# Name: 成交额, dtype: float64
