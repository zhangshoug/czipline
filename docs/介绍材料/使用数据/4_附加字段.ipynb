# %%
# %load_ext zipline

# %%
# %%zipline --start 2018-4-10 --end 2018-4-25
#
# from zipline.api import symbol
#
# def initialize(context):
#     pass
#
# def handle_data(context, data):
#     hist = data.history(symbol('000333'), ['amount','cmv','turnover'], 5, '1d')
#     print(hist)
# Out:
#                                  amount           cmv  turnover
# 2018-04-02 00:00:00+00:00  2.227710e+09  3.420337e+11     0.006
# 2018-04-03 00:00:00+00:00  1.645030e+09  3.399624e+11     0.005
# 2018-04-04 00:00:00+00:00  1.980450e+09  3.431341e+11     0.006
# 2018-04-09 00:00:00+00:00  2.210490e+09  3.320653e+11     0.007
# 2018-04-10 00:00:00+00:00  1.846470e+09  3.415806e+11     0.005
#                                  amount           cmv  turnover
# 2018-04-03 00:00:00+00:00  1.645030e+09  3.399624e+11     0.005
# 2018-04-04 00:00:00+00:00  1.980450e+09  3.431341e+11     0.006
# 2018-04-09 00:00:00+00:00  2.210490e+09  3.320653e+11     0.007
# 2018-04-10 00:00:00+00:00  1.846470e+09  3.415806e+11     0.005
# 2018-04-11 00:00:00+00:00  2.476800e+09  3.429399e+11     0.007
#                                  amount           cmv  turnover
# 2018-04-04 00:00:00+00:00  1.980450e+09  3.431341e+11     0.006
# 2018-04-09 00:00:00+00:00  2.210490e+09  3.320653e+11     0.007
# ...
